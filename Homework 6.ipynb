# %% [markdown]
# # Homework 6

# %% [markdown]
# - Student name: Minh Tran

# %% [markdown]
# ---

# %% [markdown]
# ## Imported packages

# %%
# all import statements come here like import math
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ---

# %% [markdown]
# ## Question 1

# %%
def pick():
    a = np.random.randint(0,51,5)
    b = np.random.randint(0,11,1)
    c = np.concatenate([a,b])
    return c

# %%
pick()
# Out:
# array([42, 34, 10, 27, 40,  7])

# %% [markdown]
# ---

# %% [markdown]
# # Question 2

# %%
def roll():
    a = [1,2,3,4,5,6]
    prob_A = [1/6,1/6,1/6,1/6,1/6,1/6]
    x = np.random.choice(a,p = prob_A)
    b = [1,2,3,4,5,6]
    prob_B = [1/6,1/6,1/6,1/6,1/6,1/6]
    y = np.random.choice(b, p = prob_B)
    print(x)
    print(y)
    
    if (x+y) % 2 == 0:
        print("Sum of dices is even")
    else:
        print("Sum of dices is odd")

# %%
roll()
# Out:
# 6
# 3
# Sum of dices is odd

# %% [markdown]
# ---

# %% [markdown]
# # Question 3

# %%
# step 1
width = 600
height = 600
# step 2
step_size = .5 #changed constant step size from .5 to 1 and to 5
# step 3
pos = (np.random.uniform(0, width) ,np.random.uniform(0, height))
# step 5 containing step 4
X = 10000
positions_x=[]
positions_y=[]
for i in range(X):
 # pick direction
    direction = np.random.choice([1,2,3,4])

 # move in that direction
    if direction == 1: # move to the right
        pos = (pos[0]+step_size, pos[1])
    elif direction == 2: # move down
        pos = (pos[0], pos[1]-step_size)
    elif direction == 3: # move to left
        pos = (pos[0]-step_size, pos[1])
    else: # move to up
        pos = (pos[0], pos[1]+step_size)

 # correct boundary crossings
    if pos[0] < 0: # x lower than 0
        pos = (pos[0] + step_size * 2, pos[1])
    elif pos[0] > width: # x greater than width
        pos = (pos[0] - step_size * 2, pos[1])
    elif pos[1] < 0:
        pos = (pos[0], pos[1] + step_size * 2)
    elif pos[1] > height:
        pos = (pos[0], pos[1] - step_size * 2)
    positions_x.append(pos[0])
    positions_y.append(pos[1])
    
plt.figure(figsize=(10,10))
plt.plot(positions_x, positions_y, label="Trajectory")
plt.scatter(positions_x[0], positions_y[0], color="red",s=100, label="Start position")
plt.scatter(positions_x[-1], positions_y[-1], color="k",s=100, label="End position")
plt.legend()

# %% [markdown]
# Increasing the step size resulted in a larger scale for the plot which makes sense because it is covering more ground.You can tell that it is a constant step size because theres a pattern.

# %% [markdown]
# ---

# %% [markdown]
# # Question 4

# %%
# step 1
width = 600
height = 600

# step 3
pos = (np.random.uniform(0, width) ,np.random.uniform(0, height))
# step 5 containing step 4
X = 10000
positions_x=[]
positions_y=[]
for i in range(X):
    step_size = np.random.uniform(1,2.5,1) #move step 2 into for-loop so it could change for every move
 # pick direction
    direction = np.random.choice([1,2,3,4])

 # move in that direction
    if direction == 1: # move to the right
        pos = (pos[0]+step_size, pos[1])
    elif direction == 2: # move down
        pos = (pos[0], pos[1]-step_size)
    elif direction == 3: # move to left
        pos = (pos[0]-step_size, pos[1])
    else: # move to up
        pos = (pos[0], pos[1]+step_size)

 # correct boundary crossings
    if pos[0] < 0: # x lower than 0
        pos = (pos[0] + step_size * 2, pos[1])
    elif pos[0] > width: # x greater than width
        pos = (pos[0] - step_size * 2, pos[1])
    elif pos[1] < 0:
        pos = (pos[0], pos[1] + step_size * 2)
    elif pos[1] > height:
        pos = (pos[0], pos[1] - step_size * 2)
    positions_x.append(pos[0])
    positions_y.append(pos[1])
    
plt.figure(figsize=(10,10))
plt.plot(positions_x, positions_y, label="Trajectory")
plt.scatter(positions_x[0], positions_y[0], color="red",s=100, label="Start position")
plt.scatter(positions_x[-1], positions_y[-1], color="k",s=100, label="End position")
plt.legend()

# %% [markdown]
# The constant step size had consistent step sizes so you could see the movement and it is more spread out. However, with the randomly selected step size, the steps are all over the place and is overlapping. It looks more dense and compact due to the change in step size every move. It is more random in a sense.

# %% [markdown]
# ---

# %% [markdown]
# # Question 5

# %%
# step 1
width = 600
height = 600

# step 3
pos = (np.random.uniform(0, width) ,np.random.uniform(0, height))
# step 5 containing step 4
X = 10000
positions_x=[]
positions_y=[]
for i in range(X):
    step_size = np.random.uniform(1,2.5,1) #move step 2 into for-loop so it could change for every move
    
    angle = np.random.randint(0,361,1) #random degrees 0 to 360
    pos = (pos[0]+(step_size*math.cos(math.radians(angle))),pos[1]+(step_size*math.sin(math.radians(angle)))) #changing point direction at an angle
    
    #correct boundaries
    if pos[0] < 0: # x lower than 0
        pos = (pos[0] - (step_size*math.cos(math.radians(angle))) * 2, pos[1]) #subtract to counteract
    elif pos[0] > width: # x greater than width
        pos = (pos[0] - (step_size*math.cos(math.radians(angle))) * 2, pos[1])
    elif pos[1] < 0:
        pos = (pos[0], pos[1] - (step_size*math.sin(math.radians(angle))) * 2)
    elif pos[1] > height:
        pos = (pos[0], pos[1] - (step_size*math.sin(math.radians(angle))) * 2)
    positions_x.append(pos[0])
    positions_y.append(pos[1])

plt.figure(figsize=(10,10))
plt.plot(positions_x, positions_y, label="Trajectory")
plt.scatter(positions_x[0], positions_y[0], color="red",s=100, label="Start position")
plt.scatter(positions_x[-1], positions_y[-1], color="k",s=100, label="End position")
plt.legend()

# %% [markdown]
# ---

# %% [markdown]
# # Question 6

# %% [markdown]
# ## Poisson distribution examples:
#
#   1.) Wallis (1936) studied vacancies in the U. S. Supreme Court over a 96-year period (1837-1932),
#     and found that the distribution of the number of vacancies per year could be characterized by a
#     Poisson model.(lambda = 0.5) Cole, Julio H.
#
#    Source : “Updating a Classic: ‘The Poisson Distribution and the Supreme Court’ Revisited.” Teaching Statistics, vol.    32, no.     3, Aug. 2010, pp. 78–80. DOI.org (Crossref), doi:10.1111/j.1467-9639.2009.00386.x.
#
#    2.) The number of soldiers of the Prussian army killed accidentally by horse kick per year
#     (von Bortkewitsch, 1898, p. 25).
#
#    Source: Letkowski, Jerzy. Applications of the Poisson Probability Distribution. p. 11.
#
#    3.) The number of mutations on a given strand of DNA per time unit (Wikipedia-Poisson,
#     2012).
#
#    Source: Letkowski, Jerzy. Applications of the Poisson Probability Distribution. p. 11.
#
#    4.) The number of visitors to a Web site per minute (Sharpie, De Veaux, Velleman, 2010, p.
#     654).
#
#    Source: Letkowski, Jerzy. Applications of the Poisson Probability Distribution. p. 11.
#
#    5.) The number of network failures per day (Levine, 2010, p. 197).
#
#    Source: Letkowski, Jerzy. Applications of the Poisson Probability Distribution. p. 11.

# %% [markdown]
# ## Normal distribution examples:
#  1.) Normal sample is found in R. A. Fisher's The Goodness of Fit of Regression Formulae and the Distribution of Regression Coefficients. Journal of the Royal Statistical Society, 85, No. 4. (1922), p. 599 [JSTOR search]
#
#  Source: NORMAL Distribution: Origin of the Name. https://condor.depaul.edu/ntiourir/NormalOrigin.htm. Accessed 12 Nov. 2019.
#
#  2.) Normal universe is found in W. A. Shewhart & F. W. Winters "Small Samples--New Experimental Results" Journal of the American Statistical Association, 23, (Jun., 1928), p. 145. [JSTOR search].
#
#  Source: NORMAL Distribution: Origin of the Name. https://condor.depaul.edu/ntiourir/NormalOrigin.htm. Accessed 12 Nov. 2019.
#
#  3.) Normal variate was in wide use in the 1930s and is found in Joseph Pepper's "Studies in the Theory of Sampling," Biometrika, 21, (1929), p. 239. [JSTOR search]
#
#   Source: NORMAL Distribution: Origin of the Name. https://condor.depaul.edu/ntiourir/NormalOrigin.htm. Accessed 12 Nov. 2019.
#
#   4.)  Normal deviate is found in 1925 in R. A. Fisher, Statistical Methods for Research Workers p. 47:  "Table I. shows that the normal deviate falls outside the range +/-1.598193 in 10 per cent of cases" (OED2).
#
#    Source: NORMAL Distribution: Origin of the Name. https://condor.depaul.edu/ntiourir/NormalOrigin.htm. Accessed 12 Nov. 2019.
#
#   5.) Normal distribution of the natural variability in monthly temperature anomalies for Durham, North Carolina.(Brown, P. T. (2016) Reporting on global warming: A study in headlines, Physics Today, doi:10.1063/PT.3.3310)
#
#   Source: ptbrown31. “Heat Waves: How Much Can Be Blamed on Global Warming Depends on How You Ask the Question.” Patrick T. Brown, PhD, 5 Jan. 2016, https://patricktbrown.org/2016/01/05/heat-waves-how-much-can-be-blamed-on-global-warming-depends-on-how-you-ask-the-question/.
